# %%
import yt
from yt.frontends.boxlib.data_structures import AMReXDataset

# %%
ds = AMReXDataset("plt")
# Out:
# yt : [INFO     ] 2019-07-08 14:57:09,011 Parameters: current_time              = 0.0
# yt : [INFO     ] 2019-07-08 14:57:09,012 Parameters: domain_dimensions         = [256 128   1]
# yt : [INFO     ] 2019-07-08 14:57:09,013 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-08 14:57:09,013 Parameters: domain_right_edge         = [2. 1. 1.]

# %%
s = yt.SlicePlot(ds, 'z', 'xvel')
s.annotate_particles(1.0)
s.show()
# Out:
# yt : [INFO     ] 2019-07-08 14:57:09,195 xlim = 0.000000 2.000000
# yt : [INFO     ] 2019-07-08 14:57:09,195 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-07-08 14:57:09,196 xlim = 0.000000 2.000000
# yt : [INFO     ] 2019-07-08 14:57:09,197 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-07-08 14:57:09,201 Making a fixed resolution buffer of (('boxlib', 'xvel')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
